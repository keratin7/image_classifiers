# %%
# http://pytorch.org/
from os import path
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())

accelerator = 'cu80' if path.exists('/opt/bin/nvidia-smi') else 'cpu'

# !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.3.0.post4-{platform}-linux_x86_64.whl torchvision
import torch

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:80: RuntimeWarning: The _imaging extension was built for another version of Pillow or PIL:
# Core version: 4.0.0
# Pillow version: 5.0.0
#   warnings.warn(str(v), RuntimeWarning)
# [autoreload of PIL.Image failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/extensions/autoreload.py", line 247, in check
#     superreload(m, reload, self.old_objects)
# ImportError: The _imaging extension was built for another version of Pillow or PIL:
# Core version: 4.0.0
# Pillow version: 5.0.0
# ]

# %%
# !pip install fastai
# !pip install pillow==4.0.0
# Out:
# ...
#   Using cached Pillow-4.0.0-cp36-cp36m-manylinux1_x86_64.whl
# ...
#   Found existing installation: Pillow 5.0.0
#     Uninstalling Pillow-5.0.0:
#       Successfully uninstalled Pillow-5.0.0
# ...

# %%
from fastai.conv_learner import *
import os

# %%
# !pip install kaggle
# Out:
# ...
# done
#   Stored in directory: /content/.cache/pip/wheels/56/4a/b5/93df30500029d78108fdfaace4f08fb881d27903f795a6367e
# Successfully built kaggle
# ...

# %%
# !mkdir /content/.kaggle/

# %%
# !rm /content/.kaggle/kaggle.json
# Out:
# rm: cannot remove '/content/.kaggle/kaggle.json': No such file or directory

# %%
# !mv kaggle.json /content/.kaggle/

# %%
# !chmod 600 /content/.kaggle/kaggle.json

# %%
# !kaggle competitions download -c plant-seedlings-classification
# Out:
# sample_submission.csv.zip: Downloaded 5KB of 5KB
# test.zip: Downloaded 86MB of 86MB
# train.zip: Downloaded 2GB of 2GB

# %%
os.chdir('/content/.kaggle/competitions/plant-seedlings-classification/')
# !mkdir /content/data/
# Out:
# mkdir: cannot create directory ‘/content/data/’: File exists

# %%
# !unzip train -d /content/data/
# !unzip test -d /content/data/
# Out:
# Archive:  train.zip
#    creating: /content/data/train/
#    creating: /content/data/train/Fat Hen/
#   inflating: /content/data/train/Fat Hen/5bdfa3a44.png
#   inflating: /content/data/train/Fat Hen/a86b9c0cd.png
#   inflating: /content/data/train/Fat Hen/f3f6559bf.png
#   inflating: /content/data/train/Fat Hen/946b48f62.png
#   inflating: /content/data/train/Fat Hen/4d7fd4020.png
#   inflating: /content/data/train/Fat Hen/2509e5bc5.png
#   inflating: /content/data/train/Fat Hen/e2462573b.png
#   inflating: /content/data/train/Fat Hen/7e98e4aa6.png
#   inflating: /content/data/train/Fat Hen/075cb6666.png
#   inflating: /content/data/train/Fat Hen/b43d0a350.png
#   inflating: /content/data/train/Fat Hen/afac20b21.png
#   inflating: /content/data/train/Fat Hen/4d2efbb45.png
#   inflating: /content/data/train/Fat Hen/f0923dcd6.png
#   inflating: /content/data/train/Fat Hen/180f41d53.png
#   inflating: /content/data/train/Fat Hen/bfdeafadd.png
# ...

# %%
rm test.zip /content/.kaggle/competitions/plant-seedlings-classification/sample_submission.csv.zip train.zip

# %%
os.chdir('/content/data/train/')

# %%
# !pip install glob2
# Out:
# ...
# done
#   Stored in directory: /content/.cache/pip/wheels/a0/e7/bd/160c7c868bc617b84c4593000031f6a99fea3a601568d8f4f3
# Successfully built glob2
# ...

# %%
from glob2 import glob
df = pd.DataFrame(columns=["file", "species"])

for image in glob("train/**/*.png"):
    dir_ = image.split('/')
    file_, species = dir_[-1], dir_[-2]

    df = df.append({
        "file": file_,
        "species": species.replace(" ","_")
        }, ignore_index=True)

df.to_csv('labels.csv', index=False)

# %%
df.head()
# Out:
#             file          species
# 0  1cf4ed969.png  Shepherds_Purse
# 1  5f87b1a93.png  Shepherds_Purse
# 2  b886d79e6.png  Shepherds_Purse
# 3  52e1bd10e.png  Shepherds_Purse
# 4  df376f5c7.png  Shepherds_Purse

# %%
labs = pd.read_csv('/content/data/labels.csv')
# labs['species'] = labs['species'].str.replace(" ","_")
# labs[1:5]
# labs['file']
# lab_array = np.array(labs)
# for i in range(len(lab_array)):
# lab_array[2][1].replace(" ","-")
# lab_array[2]

# %%
from sklearn.metrics import fbeta_score
def f2(preds, targs, start=0.17, end=0.24, step=0.01):
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        return max([fbeta_score(targs, (preds>th), 2, average='samples')
                    for th in np.arange(start,end,step)])

# %%
labs.to_csv('new_labels.csv', index=False)

# %%
PATH = '/content/data/train/'

# %%
# from fastai import *
n= len(labs)-1
val_idxs = get_cv_idxs(n)

# %%
# !find /content/data/train/ -type f -print0 | xargs -0 mv -t /content/data/train/

# %%
tfms = tfms_from_model(resnet50, 256, aug_tfms=transforms_top_down, max_zoom=1.4)
data = ImageClassifierData.from_csv(PATH, 'train', '/content/new_labels.csv', 64, tfms=tfms, val_idxs=val_idxs,skip_header=True)

# %%
os.chdir('/content/data/train/')

# %%
# !uptime
# Out:
#  07:15:13 up 5 min,  0 users,  load average: 0.20, 0.62, 0.35

# %%
x,y = next(iter(data.val_dl))
plt.imshow(data.val_ds.denorm(to_np(x))[5]*1.3)

# %%
learn = ConvLearner.pretrained(resnet50, data, metrics=[accuracy_np], precompute=True)

# %%
# !ls -d  */ | xargs rm -rf
# !ls -d */

# %%
def getdata(sz):
  tfms = tfms_from_model(resnet50, 256, aug_tfms=transforms_top_down, max_zoom=1.4)
  data = ImageClassifierData.from_csv(PATH, 'train', '/content/data/labels.csv', 64, tfms=tfms, val_idxs=val_idxs,test_name="test",skip_header=True)
  return data

# %%
data = getdata(256)

# %%
def accuracy_own(preds, targs):
     return accuracy_multi(preds, targs, 0.5)

# %%
learn.set_data(getdata(512))

# %%
def accuracy_np(preds, targs):
  preds = np.argmax(preds, 1)
  return (preds==targs).mean()
# learn.metrics = [accuracy_np]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-6d74e90d76eb> in <module>()
#       2   preds = np.argmax(preds, 1)
#       3   return (preds==targs).mean()
# ----> 4 learn.metrics = [accuracy_np]
#
# NameError: name 'learn' is not defined

# %%
learn.lr_find()
# Out:
# ...
#  85%|████████▌ | 51/60 [00:00<00:00, 68.62it/s, loss=10.1]

# %%
learn.sched.plot_lr()

# %%
learn.freeze()
learn.fit(1e-2, 5)
# Out:
# ...
#   0%|          | 0/60 [00:00<?, ?it/s]
#
#   0%|          | 0/60 [00:04<?, ?it/s, loss=0.000781]
#
#   2%|▏         | 1/60 [00:04<04:07,  4.20s/it, loss=0.000781]
#
#   2%|▏         | 1/60 [00:05<05:42,  5.81s/it, loss=0.0242]
#
#   3%|▎         | 2/60 [00:05<02:49,  2.93s/it, loss=0.0242]
#
#   3%|▎         | 2/60 [00:08<04:08,  4.29s/it, loss=0.0161]
#
#   5%|▌         | 3/60 [00:08<02:43,  2.87s/it, loss=0.0161]
#
#   5%|▌         | 3/60 [00:09<02:59,  3.15s/it, loss=0.0121]
#
#   7%|▋         | 4/60 [00:09<02:12,  2.37s/it, loss=0.0121]
#
#   7%|▋         | 4/60 [00:10<02:24,  2.58s/it, loss=0.0111]
#
#   8%|▊         | 5/60 [00:10<01:53,  2.07s/it, loss=0.0111]
#
#   8%|▊         | 5/60 [00:11<02:02,  2.23s/it, loss=0.00975]
#
#  10%|█         | 6/60 [00:11<01:40,  1.86s/it, loss=0.00975]
#
#  10%|█         | 6/60 [00:11<01:47,  1.99s/it, loss=0.00834]
#
#  12%|█▏        | 7/60 [00:12<01:31,  1.72s/it, loss=0.00834]
#
# ...

# %%
learn.precompute=False
learn.unfreeze()
lrs = [(1e-2)/10, (1e-2)/5, 1e-2]
# learn.precompute = False
learn.fit(lrs, 3, cycle_len=1, cycle_mult=2)
# Out:
# ...
# [0.      0.71774 0.35752 0.89514]
# [1.      0.42886 0.2272  0.92809]
# [2.      0.286   0.17003 0.9431 ]
# [3.      0.23516 0.31649 0.90934]
# [4.      0.19873 0.20727 0.93559]
#  80%|████████  | 48/60 [01:47<00:26,  2.24s/it, loss=0.155]
# [5.      0.15691 0.1496  0.95039]
# [6.      0.11522 0.14117 0.95039]

# %%
learn.freeze()
learn.fit(1e-1,10)
# Out:
# ...
# [0.      0.10778 0.12737 0.95373]
# [1.      0.11475 0.13405 0.95061]
# [2.      0.08855 0.14615 0.94957]
# [3.      0.09454 0.14251 0.94727]
# [4.      0.09555 0.18538 0.93976]
#  78%|███████▊  | 47/60 [00:57<00:16,  1.23s/it, loss=0.0988]
# [5.      0.09775 0.1305  0.95686]
# [6.      0.09006 0.17156 0.94436]
# [7.      0.08942 0.13168 0.95812]
# [8.      0.09148 0.1346  0.95395]
# [9.      0.07838 0.14833 0.95165]

# %%
learn.unfreeze()
learn.fit(lrs, 10, cycle_len=2, cycle_mult=2)
# Out:
# ...
# [0.      0.10753 0.12982 0.95603]
# [1.      0.09066 0.12794 0.95708]
# [2.      0.11327 0.15262 0.94809]
# [3.      0.10372 0.11325 0.96311]
# [4.      0.0787  0.10722 0.97062]
#  78%|███████▊  | 47/60 [01:45<00:29,  2.24s/it, loss=0.0725]
# [5.      0.07281 0.10765 0.96853]
# [6.      0.07587 0.16895 0.94957]
# [7.      0.07003 0.17016 0.94558]
# [8.      0.06619 0.14703 0.95456]
# [9.      0.05918 0.13324 0.95894]
#  98%|█████████▊| 59/60 [02:08<00:02,  2.17s/it, loss=0.0525]
# [10.       0.05252  0.13924  0.95018]
# [11.       0.04333  0.11949  0.95643]
# [12.       0.04035  0.10148  0.96268]
# [13.       0.03574  0.1131   0.96415]
# [14.       0.05418  0.15042  0.95725]
#  78%|███████▊  | 47/60 [01:45<00:29,  2.25s/it, loss=0.0574]
# [15.       0.05795  0.12892  0.95769]
# [16.       0.05486  0.17045  0.94102]
# [17.       0.05563  0.15873  0.95291]
# [18.       0.0498   0.19355  0.93768]
# [19.       0.03742  0.12561  0.96164]
# ...

# %%
learn.save('restnet50_5')

# %%
files.download('/content/data/models/resnet50_2.h5')

# %%
learn.sched.plot_loss()

# %%
learn.fit(1e-1, 2, cycle_len=1, cycle_mult=2)
# Out:
# ...
#   0%|          | 0/60 [00:00<?, ?it/s]
#
#   0%|          | 0/60 [00:03<?, ?it/s, loss=0.000359]
#
#   2%|▏         | 1/60 [00:03<03:54,  3.97s/it, loss=0.000359]
#
#   2%|▏         | 1/60 [00:05<05:44,  5.85s/it, loss=0.00067]
#
#   3%|▎         | 2/60 [00:05<02:50,  2.94s/it, loss=0.00067]
#
#   3%|▎         | 2/60 [00:07<03:41,  3.81s/it, loss=0.00275]
#
#   5%|▌         | 3/60 [00:07<02:25,  2.56s/it, loss=0.00275]
#
#   5%|▌         | 3/60 [00:08<02:41,  2.84s/it, loss=0.00227]
#
#   7%|▋         | 4/60 [00:08<01:59,  2.13s/it, loss=0.00227]
#
#   7%|▋         | 4/60 [00:09<02:10,  2.34s/it, loss=0.00187]
#
#   8%|▊         | 5/60 [00:09<01:43,  1.88s/it, loss=0.00187]
#
#   8%|▊         | 5/60 [00:10<01:51,  2.02s/it, loss=0.00161]
#
#  10%|█         | 6/60 [00:10<01:31,  1.69s/it, loss=0.00161]
#
#  10%|█         | 6/60 [00:10<01:38,  1.83s/it, loss=0.00177]
#
#  12%|█▏        | 7/60 [00:10<01:23,  1.57s/it, loss=0.00177]
#
# ...

# %%
learn.reg_fn = ps[0.5,0.5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-121-d901888c92e0> in <module>()
# ----> 1 learn.reg_fn = ps[0.5,0.5]
#
# NameError: name 'ps' is not defined

# %%
# !rm -r /content/data/train/**/

# %%
def getdata(sz):
  tfms = tfms_from_model(resnet50, 256, aug_tfms=transforms_top_down, max_zoom=1.4)
  data = ImageClassifierData.from_csv(PATH, 'train', '/content/new_labels.csv', 64, tfms=tfms, val_idxs=val_idxs,test_name="test",skip_header=True)
  return data

# %%
learn.set_data(getdata(256))

# %%
files.download('/content/data/labels.csv')

# %%
data = getdata(256)

# %%
multi_probs,y = learn.TTA(is_test=False)
probs = np.mean(multi_probs,0)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
#
#  25%|██▌       | 1/4 [00:14<00:43, 14.64s/it]
#
#  50%|█████     | 2/4 [00:29<00:29, 14.67s/it]
#
#  75%|███████▌  | 3/4 [00:44<00:14, 14.75s/it]
#
# 100%|██████████| 4/4 [00:58<00:00, 14.74s/it]

# %%
sklearn.metrics.f1_score(y,np.argmax(np.exp(multi_probs),axis=1),average='micro')
# Out:
# 0.9841938883034773

# %%
np.argmax(np.exp(multi_probs),axis=1)
# Out:
# array([11, 11,  2,  3,  3, 10,  8,  7,  4,  9, 11, 10,  1,  7,  5,  8,  8,  1,  5,  3,  8,  9,  6,  2, 10,
#         3,  3, 10,  8,  6,  2, 10, 11,  0,  0,  3,  9,  6,  6,  7,  5,  8,  3,  4,  3, 10,  1,  3,  8,  3,
#         5,  1,  3,  9,  8,  1,  2,  6,  2,  3,  1, 10,  8,  6,  0,  5,  1,  8,  8,  8, 11, 11,  5,  3, 11,
#         1,  6, 10,  3,  5, 11, 10,  6,  4,  8,  5,  4,  8, 11,  4, 10,  6,  9,  3,  3,  5,  9,  3,  5,  9,
#         3,  0,  7,  6, 10,  1,  6,  6,  9,  6,  6,  8,  1,  7, 10,  9,  5,  6,  3,  5,  6,  4, 10,  4,  0,
#         9,  1, 11,  3,  2,  5,  9, 11,  4,  1,  1,  3,  1,  3,  8,  1,  6,  6,  1,  1,  3, 11,  3,  3, 10,
#         8,  6,  3,  6,  2,  5,  5,  6,  2, 10,  6,  5,  3,  2,  6,  5,  8,  8, 10, 10, 10, 11, 10, 11, 11,
#         3, 11,  3, 11, 10,  5,  8,  7,  3,  7,  8, 10,  5,  8, 11,  5,  4,  3,  6,  3,  5, 10,  0,  3,  1,
#        10, 11,  1,  8,  3,  6,  8,  1,  4,  2,  1,  1,  7,  6,  5,  1,  3,  2,  7,  2, 10,  8,  3,  5,  7,
# ...

# %%
learn.save('resnet50_working')

# %%
from google.colab import files
files.download('/content/data/models/resnet50_working.h5')

# %%
# test_probs = learn.TTA(is_test=True)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-229-f2e37d3030cd> in <module>()
# ----> 1 test_probs = learn.TTA(is_test=True)
#
# /usr/local/lib/python3.6/dist-packages/fastai/learner.py in TTA(self, n_aug, is_test)
#     169         preds1,targs = predict_with_targs(self.model, dl1)
#     170         preds1 = [preds1]*math.ceil(n_aug/4)
# --> 171         preds2 = [predict_with_targs(self.model, dl2)[0] for i in tqdm(range(n_aug), leave=False)]
#     172         return np.stack(preds1+preds2).mean(0), targs
#     173
#
# /usr/local/lib/python3.6/dist-packages/fastai/learner.py in <listcomp>(.0)
#     169         preds1,targs = predict_with_targs(self.model, dl1)
#     170         preds1 = [preds1]*math.ceil(n_aug/4)
# ...

# %%
data = getdata(256)

# %%
len(data.test_ds)
# Out:
# 794

# %%
mean_test_probs = np.mean(test_probs,0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-87153f1e3cb6> in <module>()
# ----> 1 mean_test_probs = np.mean(test_probs,0)
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py in mean(a, axis, dtype, out, keepdims)
#    2955
#    2956     return _methods._mean(a, axis=axis, dtype=dtype,
# -> 2957                           out=out, **kwargs)
#    2958
#    2959
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims)
#      52
#      53 def _mean(a, axis=None, dtype=None, out=None, keepdims=False):
# ---> 54     arr = asanyarray(a)
#      55
#      56     is_float16_result = False
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/numeric.py in asanyarray(a, dtype, order)
#     542
#     543     """
# --> 544     return array(a, dtype, copy=False, order=order, subok=True)
#     545
# ...

# %%
log_preds,y = learn.TTA(is_test=True)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
#
#  25%|██▌       | 1/4 [00:11<00:33, 11.00s/it]
#
#  50%|█████     | 2/4 [00:22<00:22, 11.01s/it]
#
#  75%|███████▌  | 3/4 [00:33<00:11, 11.04s/it]
#
# 100%|██████████| 4/4 [00:44<00:00, 11.06s/it]

# %%
# log_preds[0]
log_preds_test = np.argmax(np.exp(log_preds), axis=1)
preds_classes = [data.classes[i].replace("_", " ") for i in log_preds_test]
# probs = np.exp(log_preds_test)
log_preds_test[6]
# Out:
# 9

# %%
preds_classes[:5]
# Out:
# ['Charlock', 'Charlock', 'Scentless Mayweed', 'Cleavers', 'Loose Silky-bent']

# %%
# index = np.argmax(log_preds, axis=1)
# pred_classes = [data.classes[i].replace("_"," ") for i in index]

# %%
# print(len(data.test_ds))
# print(len(data.val_ds))
# Out:
# 794
# 949

# %%
pred_classes[6]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-115-164c51b47537> in <module>()
# ----> 1 pred_classes[6]
#
# NameError: name 'pred_classes' is not defined

# %%
len(data.train_ds)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-241-6fc143e58cd7> in <module>()
# ----> 1 len(data.train_ds)
#
# AttributeError: 'ImageClassifierData' object has no attribute 'train_ds'

# %%
df = pd.DataFrame(columns=["file", "species"])

for image in glob("train/**/*.png"):
    dir_ = image.split('/')
    file_, species = dir_[-1], dir_[-2]

    df = df.append({
        "file": file_,
        "species": species
        }, ignore_index=True)

df.to_csv('labels.csv', index=False)

# %%
sub_df = pd.DataFrame(columns=["file", "species"])
for i in range(len(data.test_ds.fnames)):
  sub_df = sub_df.append({"file":data.test_ds.fnames[i].split('/')[1],"species":preds_classes[i]}, ignore_index=True)
  
sub_df.to_csv('submission3.csv', index=False)

# %%
files.download('submission3.csv')

# %%
# !kaggle competitions submit -c plant-seedlings-classification -f 'submission3.csv' -m "Overfitting"
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 11, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.6/dist-packages/kaggle/cli.py", line 18, in main
#     out = args.func(**command_args)
#   File "/usr/local/lib/python3.6/dist-packages/kaggle/api/kaggle_api_extended.py", line 66, in competitionSubmit
#     urlResult = self.competitions_submissions_url(file_name = os.path.basename(file), content_length = os.path.getsize(file), last_modified_date_utc = int(os.path.getmtime(file) * 1000))
#   File "/usr/local/lib/python3.6/dist-packages/kaggle/api/kaggle_api.py", line 670, in competitions_submissions_url
#     (data) = self.competitions_submissions_url_with_http_info(content_length, last_modified_date_utc, **kwargs)  # noqa: E501
#   File "/usr/local/lib/python3.6/dist-packages/kaggle/api/kaggle_api.py", line 757, in competitions_submissions_url_with_http_info
#     collection_formats=collection_formats)
# ...

# %%
new_df = pd.read_csv('/content/submission.csv')
new_df.head()
# Out:
#             file    species
# 0  cbe761896.png   Charlock
# 1  808578ed5.png   Charlock
# 2  90d119d25.png  Scentless
# 3  6bce55e05.png   Cleavers
# 4  026716f9b.png      Loose

# %%
# !kaggle competitions submit -c plant-seedlings-classification -f submission.csv -m "First Attempt. KMN"
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 11, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.6/dist-packages/kaggle/cli.py", line 18, in main
#     out = args.func(**command_args)
#   File "/usr/local/lib/python3.6/dist-packages/kaggle/api/kaggle_api_extended.py", line 66, in competitionSubmit
#     urlResult = self.competitions_submissions_url(file_name = os.path.basename(file), content_length = os.path.getsize(file), last_modified_date_utc = int(os.path.getmtime(file) * 1000))
#   File "/usr/local/lib/python3.6/dist-packages/kaggle/api/kaggle_api.py", line 670, in competitions_submissions_url
#     (data) = self.competitions_submissions_url_with_http_info(content_length, last_modified_date_utc, **kwargs)  # noqa: E501
#   File "/usr/local/lib/python3.6/dist-packages/kaggle/api/kaggle_api.py", line 757, in competitions_submissions_url_with_http_info
#     collection_formats=collection_formats)
# ...

# %%
learn2 = ConvLearner.pretrained(resnet50, data)

# %%
learn2.sched.plot()

# %%
learn2.fit(1e-1,2)
